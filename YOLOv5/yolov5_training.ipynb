# %%
import torch
model = torch.load('../runs/detect/train25/weights/best.pt')

# %%
model.train(data = './custom_data.yaml', resume = True, epochs = 50, imgsz = 416, device = 'mps', pretrained = True, patience = 15)
# Out:
# Ultralytics YOLOv8.0.146 🚀 Python-3.8.16 torch-2.0.1 MPS (Apple M2 Max)
# ...

# %%
metrics = model.val(device = 'mps')
metrics.box.map
metrics.box.map50
metrics.box.map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.146 🚀 Python-3.8.16 torch-2.0.1 MPS (Apple M2 Max)
# val: Scanning /Users/jared/Documents/ds_study/project(brand)/yolo_train/content/
#                  Class     Images  Instances      Box(P          R      mAP50  mlibpng warning: iCCP: known incorrect sRGB profile
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        900       1150       0.66      0.654      0.716      0.679
#                bicycle        900        227          0          0     0.0148      0.014
#                    car        900        371      0.915      0.488      0.768      0.746
#             motorcycle        900        216      0.979      0.883      0.985      0.869
#                    bus        900        185      0.851      0.987      0.984      0.964
#                  truck        900        151      0.554      0.914      0.831        0.8
# ...
